# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhayanshariff/Task-5-Codekata-Score-Assessment-/blob/main/Source_Code/Task_4_Assignment_College_Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1=pd.read_csv("college_1.csv")
df2=pd.read_csv("college_2.csv")

# %%
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
df_main = pd.merge(df1,df2,how="outer")
df_main.fillna(0,inplace=True)
df_main.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py:1204: UserWarning:
#
# You are merging on int and float columns where the float values are not equal to their int representation
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
exceeded_expectations = df_main[df_main["CodeKata Score"]>15000]
exceeded_expectations.to_csv("Exceeded expectation.csv")
exceeded_expectations
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        0.0
# 1         Computer Science and Engineering       0        0.0
# 2         Computer Science and Engineering       0        0.0
# 84  Electronics and Electrical Engineering       0        0.0
#
#     computational_thinking
# 0                      0.0
# 1                      0.0
# 2                      0.0
# 84                     9.0

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
reached_expectations = df_main[df_main["CodeKata Score"].between(10000,15000)]
reached_expectations.to_csv("Reached_expectations.csv")
reached_expectations
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3         Mugunthan S   100.0   47.0              10610           10610
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 87    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                    Department  Rising  python_en  \
# 3            Computer Science and Engineering       0        0.0
# 85           Computer Science and Engineering     340       20.0
# 86           Computer Science and Engineering    2000       55.0
# 87  Electronics and Communication Engineering       0        0.0
#
#     computational_thinking
# 3                      0.0
# 85                     0.0
# 86                     6.0
# 87                    -1.0

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
needs_Improvement = df_main[df_main["CodeKata Score"].between(7000,10000)]
needs_Improvement.to_csv("Needs_Improvement.csv")
needs_Improvement
# Out:
#                        Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4               Sathammai.S   100.0    8.0               8980            8980
# 5              NIVEESHWAR S   100.0    0.0               8200            8200
# 6             KALAIARASAN K    85.0   47.0               7750            7880
# 7      MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 88                VIINU V P    -1.0   24.0               9150            9150
# 89               Poojitha Y     0.0   35.0               7210            8970
# 90   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 91                Gowtham R    -1.0    4.0               8650            8650
# 92                 shifak N    58.0    0.0               5180            8320
# 93                  Balaji     -1.0   20.0               6170            8160
# 94                 Rushitha    -1.0   62.0               7470            8090
# ...

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
unsatisfactory = df_main[df_main["CodeKata Score"]<7000]
unsatisfactory.to_csv("Unsatisfactory.csv")
unsatisfactory
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8         J.SUGANTHI    27.0  50.00               5860            5860
# 9       thamizhpaana    29.0   0.00               5500            5500
# 10   Iyappan Samiraj    50.0  24.00               5400            5400
# 11      Ponniyamma.R   100.0  11.25               5380            5380
# 12         SABAPATHI   100.0   0.00               5280            5280
# ..               ...     ...    ...                ...             ...
# 114    praveen raj j    24.0   0.00               2380            2380
# 115       AMARNATH D    -1.0  12.00               1890            1890
# 116             bala    32.0   0.00               1720            1720
# 117             XY Z    -1.0  -1.00                  0               0
# 118        Hariharan    -1.0  -1.00                  0               0
#
#                                     Department  Rising  python_en  \
# ...

# %% [markdown]
# Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
print("Previous GeekCoins Average:", df_main['Previous Geekions'].mean())
print("Present GeekCoins(CodeKata) Average :", df_main['CodeKata Score'].mean())
print("\n\n")

plt.barh("Previous Geekions",df_main['Previous Geekions'].mean(),height=0.7)
plt.barh("Current Geekions",df_main['CodeKata Score'].mean(),height=0.7,color = 'silver')
plt.title("Previous Geekions vs Current Geekions")
plt.show()
# Out:
# Previous GeekCoins Average: 3842.3529411764707
# Present GeekCoins(CodeKata) Average : 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
print("Number of students participated: ",df_main['Name'].count())
# Out:
# Number of students participated:  119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
#calculated from merged Dataframe as they are present in both 1st and 2nd CSV
print("Python Average completion :",df_main['python'].mean()) 
print("Mysql Average Completion :" ,df_main['mysql'].mean())

#calculated from 2nd Dataframe as they are only present in 2nd CSV
print("Python_English Average Completion :" ,df2['python_en'].mean()) 
print("Compuational Thinking Average Completion :", df2['computational_thinking'].mean())
# Out:
# Python Average completion : 54.35294117647059
# Mysql Average Completion : 23.5
# Python_English Average Completion : 29.65714285714286
# Compuational Thinking Average Completion : 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
rising_star = df_main.nlargest(3,'Rising')
rising_star
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking
# 92                      0.0
# 86                      6.0
# 102                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
shining_star = df_main.nlargest(3,'Previous Geekions')
shining_star
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import plotly.express as px
ck_performance_chart=px.pie(df_main,names='Department',values='CodeKata Score',title='Department wise codekata performence')
ck_performance_chart
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
#I am selecting the toppers based on Codekata score
department_wise_toppers = df_main.pivot_table(index = 'Department', values = ['Name','CodeKata Score'], aggfunc = 'max')
department_wise_toppers
# Out:
#                                            CodeKata Score            Name
# Department
# Computer Science and Engineering                    24500     vijayakumar
# Electronics and Communication Engineering           10040       vignesh B
# Electronics and Electrical Engineering              19400  yaser ahamed.A

# %%
x = ['CSE', 'ECE', 'EEE']
y = department_wise_toppers['CodeKata Score']
plt.barh(x,y, height = 0.5)
plt.title("Department wise Toppers")
plt.xlabel("CodeKata Score")
plt.ylabel("Departments")
plt.show()
